# %%
# Import packages

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open('aircraft.png') 

left = 210
top = 150
right = 310
bottom = 300
me = img.crop((left, top, right, bottom))

rgb_im = me.convert('RGB')
rgb_im.save('cropped.jpeg')
rgb_im
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x24833DC3748>
